# %%
import pandas as pd
df = pd.read_excel('./dataset/랜섬웨어/원문데이터_랜섬웨어.xlsx',
                   names=['TEXT', 'LINK', 'TEXT2', 'METHOD', 'TYPE', 'DATE', 'DATA2'])
df
# Out:
#                                                    TEXT  \
# 0     RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# 1     RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# 2     RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# 3     RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# 4     RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# ...                                                 ...
# 9602                  텍스트 마이닝을 이용한 정보보호인식 분석 및 강화 방안 모색
# 9603                        사이버 공격탐지와 싱글 패턴 매칭 알고리즘 개선법
# 9604          해킹이 산업보안에 미치는 영향에 대한 연구 : 사회 공학적 해킹을 중심으로
# 9605                                           보안 관련 기사
# 9606                          딥러닝 기반의 악성코드 예방 모델에 관한 연구
#
#                                                    LINK  \
# 0     https://twitter.com/i/web/status/1306071247256...
# 1     https://twitter.com/i/web/status/1306060564611...
# 2     https://twitter.com/i/web/status/1306058919605...
# 3     https://twitter.com/i/web/status/1306056529733...
# 4     https://twitter.com/i/web/status/1306055533317...
# ...                                                 ...
# 9602  http://academic.naver.com/article.naver?doc_id...
# 9603  http://academic.naver.com/article.naver?doc_id...
# 9604  http://academic.naver.com/article.naver?doc_id...
# 9605  http://academic.naver.com/article.naver?doc_id...
# 9606  http://academic.naver.com/article.naver?doc_id...
#
#                                                   TEXT2   METHOD      TYPE  \
# 0                                                   NaN  twitter       all
# 1                                                   NaN  twitter       all
# 2                                                   NaN  twitter       all
# 3                                                   NaN  twitter       all
# 4                                                   NaN  twitter       all
# ...                                                 ...      ...       ...
# 9602  최근 정보보호 분야에서는 사회공학, 랜섬웨어와 같은 정보보호 기술만으로는 막을 수 ...    naver  academic
# 9603  표제지목차I. 서론 7II. 악성코드 101절 악성코드란 102절 악성코드의 종류 ...    naver  academic
# 9604  표제지목차국문초록 5제I장 서론 7제1절 연구배경 및 목적 7제2절 연구범위와 방법...    naver  academic
# 9605  더존비즈온, 포렌식 기반 DLP 솔루션 공급 잇따라경찰청 위장한 악성코드 이메일 확...    naver  academic
# 9606  Ⅰ. 서론 11.1 연구의 배경 11.2 연구의 필요성 31.3 논문의 구성 5Ⅱ....    naver  academic
#
#             DATE       DATA2
# 0     2019-09-22  2020-09-22
# 1     2019-09-22  2020-09-22
# 2     2019-09-22  2020-09-22
# 3     2019-09-22  2020-09-22
# 4     2019-09-22  2020-09-22
# ...          ...         ...
# 9602  2019-09-22  2020-09-22
# 9603  2019-09-22  2020-09-22
# 9604  2019-09-22  2020-09-22
# 9605  2019-09-22  2020-09-22
# 9606  2019-09-22  2020-09-22
#
# [9607 rows x 7 columns]

# %%
df['TEXT']
# Out:
# 0       RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# 1       RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# 2       RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# 3       RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
# 4       RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(....
#                               ...
# 9602                    텍스트 마이닝을 이용한 정보보호인식 분석 및 강화 방안 모색
# 9603                          사이버 공격탐지와 싱글 패턴 매칭 알고리즘 개선법
# 9604            해킹이 산업보안에 미치는 영향에 대한 연구 : 사회 공학적 해킹을 중심으로
# 9605                                             보안 관련 기사
# 9606                            딥러닝 기반의 악성코드 예방 모델에 관한 연구
# Name: TEXT, Length: 9607, dtype: object

# %%
texts =df['TEXT'].values.tolist()
print(texts)
# Out:
# ['RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', '안랩, 채용 문서 위장 랜섬웨어 유포 주의 당부 https://t.co/nwEeOZUcrT', "하반기 기업공채 속 '이력서','포트폴리오','입사지원서' 위장한 랜섬웨어 주의보 #이력서 #포토폴리오 #입사지원서 #랜섬웨어 #주의 https://t.co/khRbfdnRW6", 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', '이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', '라떼는 말이여...트로이목마 바이러스가...제일로..무서웠어... 에이 할무니 그거 언제적 바이러스예요~ 그나저나 할머니 저 랜섬웨어 걸렸는데 이거 풀려면 3천달러 입금하래요 이 씨불놈이', '트로이목마 나 초딩때 유행했던가 암튼 그때는 무서운 바이러스였음 요즘은 처리가 쉬워짐 ㅎㅎ 근데 랜섬웨어 걸리면 이제 개좆되는거임', '@heroberie9752 랜섬웨어 걸리셨어여...?', '새끼들아 암만 그래도 이건 아니지.. 랜섬웨어 공격으로 독일 병원서 여성 환자 숨져 | 다음 뉴스 https://t.co/p16w8GmByv', 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', 'RT @bloter_news: 이력서 입사지원서 등 HWP PDF 위장 실행파일(.exe) 열면 랜섬웨어 감염 https://t.co/p7cFf0ZT3Q', 'RT @HIPPO_362: 라떼는 말이여...트로이목마 바이러스가...제일로..무서웠어... 에이 할무니 그거 언제적 바이러스예요~ 그나저나 할머니 저 랜섬웨어 걸렸는데 이거 풀려면 3천달러 입금하래요 이 씨불놈이', '할무니 요즘 트로이는 약해요 랜섬웨어 ㄱ', 'CGV 광고 먹통…국내 랜섬웨어 공격 주의보', '[ 영어회화 VLOG ] 원클릭 초간단 랜섬웨어 예방법 (복잡한 PC 보안 변경 X)', '랜섬웨어 공격…&quot;스마트폰도 안전하지 않다&quot; / YTN 사이언스', '게임 점수를 요구하는 랜섬웨어 rensenware!! (rootkim)', '#34 시스코 엄브렐라 소개영상(랜섬웨어 방어) Cisco Umbrella', '랜섬웨어, 바이러스, 악성코드 등 예방하기', '사상 최악의 바이러스! 랜섬 웨어에 걸린 필메 # crypz [BJ필메]', '랜섬웨어 피하고 싶은 사람들을 위한 추천 영상', '랜섬웨어 만들어서 딥웹에 배포하기 실화냐? 그 와중에 테스트하던 시청자 컴퓨터 와장창ㅋㅋㅋㅋㅋ | 청일 TV', '미래부, &#39;랜섬웨어&#39; 추가 공격 대비 민·관 협의체 구성 / YTN 사이언스', '이걸 안 하면 컴퓨터가 해킹당한다?! 긴급 랜섬웨어 대처방법 [사모장]', 'CGV 일부 상영관 광고서버 랜섬웨어 감염 / 연합뉴스TV (YonhapnewsTV)', '[노가리][2] 2016년 6월 4일 랜섬웨어 걸린방송의 노가리', '[랜섬웨어 복구방법]랜섬웨어 감염 ㅠㅠ 메그니베르 감염시 증상 망했습니다.', '랜섬웨어감염', '이녕♥ 영알못의 믹스메타 창시자 (feat. 랜섬웨어?) [오버워치]', 'UNBS 지식잇기 - 최악의 악성코드 랜섬웨어 [2편]', '병원 PC도 코로나 감염...&#39;랜섬웨어&#39; 기승 / 학원·종교시설 &#39;운영 중단&#39; 해제 /국민 72% “코로나 방역 따른 불편 감수”/  “민간 병·의원, 공공의료 배제 안 돼”', '[Security] 70여개국을 강타한 사상 최악의 랜섬웨어, WanaCrypt0r 2.0 바이러스', 'AppCheck 랜섬웨어 백신 : Cerber 랜섬웨어 차단 영상', '컴퓨터 파일이 안 열리는데 돈을 달라네요 | 랜섬웨어에 걸리면 돈 줘야 할까요?', '[가상머신]워너크라이 랜섬웨어 실행영상', '데스노트 랜섬웨어? 시니가미 락커(Shinigami Locker, しにがみ)에 걸려보았습니다.Shinigami - 와라! 랜섬웨어 [초다]', '순간포착! 랜섬웨어에 감염되는 순간!', '[랜섬웨어 예방 및 사이버 보안](3)-디도스, 웹사이트를 마비시키는 분산 서비스 공격', '랜섬웨어 원인, 증상, 대처법. 그리고 사진가를 위한 사진백업 방법', '[ INFO ] Petya 랜섬웨어 분석', '올해 상반기 랜섬웨어 피해 4,540건…작년치 3배 / YTN 사이언스', '윈도우 디펜더( Windows Defender) 에서 랜섬웨어 방지 설정하기', '워너크라이(랜섬웨어), 최악의 상황은 면하다?', '[Security] Ransomware(랜섬웨어) 바이러스 1번, CTB LOCKER', 'AppCheck 안티랜섬웨어 for 윈도우 서버', '[뉴스] 캐논 랜섬웨어 해킹, F값 변환 렌즈 펌웨어, 소니 보급형 풀프 카메라, 니콘 웹캠 펌웨어, 니콘 남아공 인종차별 인파만파, 시그마 신 아트 85mm, 얼굴인식 회피', '인터넷디스크 랜섬웨어 복구 동영상', '철구 컴퓨터에 또 랜섬웨어?! 다 지워진 파일, 바이러스 심은놈 꼭 찾아낸다 (17.02.10-2) :: ChulGu', 'RansomDefnder (랜섬디펜더) - Corona 랜섬웨어 방어 영상 (Anti-Ransomware)', '윈도우 취약점 악용 신종 랜섬웨어 발견 … 예방법은? / CBCNEWS, CBCTV', '내가 첫손님이라고? 큐베이스를 설치했더니 랜섬웨어 갠드크랩 v5.0.3이 공짜! (GANDCRAB v5.0.3)', 'AhnLab MDS, 랜섬웨어 대응 시나리오', '저... 랜섬웨어 걸렸습니다 ㅠㅠ(마인크래프트 모드 다운로드를 사칭한 랜섬웨어)', '랜섬웨어 방어 교육 동영상', 'RansomDefnder (랜섬디펜더) - Sodinokibi 랜섬웨어 방어 영상 (Anti-Ransomware)', '[죠죠]랜섬웨어에 걸린 보스', '인터넷나야나 &quot;랜섬웨어 피해 복구 중&quot; / YTN 사이언스', '워너크라이 랜섬웨어 Wannacry Ransomeware 예방방법, 한국인터넷진흥원, 보호나라에서 권고하는 방법', '공지사항-랜섬웨어 바이러스에 감염되었어요- 하스스톤 기무기훈 공지사항 hearthstone', '[랜섬웨어 예방 및 사이버 보안](3)-디도스, 웹사이트를 마비시키는 분산 서비스 공격', '랜섬웨어 예방, 방지 하는법, 안티랜섬웨어 툴로 확실하게 차단, 방어, 대처하자', '매그니베르 랜섬웨어 막는 법', '[충격실화] 신종 랜섬웨어에 감염된 통신장비 전문업체의 운명은?', '컴퓨터 켰더니 &quot;돈 보내라&quot; 협박…랜섬웨어 주의보', '유튜버들을 노린 유튜브 랜섬웨어 주의령!', '체르노빌 원전 방사능 감시시스템도 &#39;랜섬웨어&#39; 공격받아 / 연합뉴스TV (YonhapnewsTV)', '악성 바이러스 &#39;랜섬 ...

# %%
from krwordrank.hangle import normalize

texts = [normalize(text, english=True, number=True) for text in texts]

# %%
from krwordrank.word import KRWordRank

wordrank_extractor = KRWordRank(
    min_count = 5, # 단어의 최소 출현 빈도수 (그래프 생성 시)
    max_length = 10, # 단어의 최대 길이
    verbose = True
    )

beta = 0.85    # PageRank의 decaying factor beta
max_iter = 10

keywords, rank, graph = wordrank_extractor.extract(texts, beta, max_iter)
# Out:
# scan vocabs ...
# num vocabs = 7553
# done = 10

# %%
for word, r in sorted(keywords.items(), key=lambda x: x[1], reverse=True)[:30]:
    print('%8s:\t%.4f' % (word, r))
# Out:
#       랜섬:	72.2724
#       39:	51.8083
#      com:	41.7577
#       보안:	23.4333
#     quot:	21.7250
#       34:	17.8530
#       방법:	13.9851
#       복구:	12.9051
#      www:	12.6090
#       주의:	12.5071
#       안랩:	12.1417
#      컴퓨터:	11.7131
#       공격:	10.7776
#       파일:	10.5081
#       감염:	10.4245
#      윈도우:	10.0911
#      사이버:	10.0653
#       기업:	9.9101
#       위장:	9.8764
#       알약:	9.4076
#      코로나:	8.9113
#     바이러스:	8.8904
#       등장:	8.8805
#       차단:	8.5025
#       수칙:	8.4351
#      어떻게:	7.6501
#       20:	7.4865
#       출시:	7.4416
# RansomBlox랜섬웨어:	7.0732
#       표적:	7.0226

# %%
stopwords = {'39', 'com', '34'}
passwords = {word: score for word, score in sorted(
    keywords.items(), key=lambda x: -x[1])[:300] if not (word in stopwords)}

# %%
from krwordrank.word import summarize_with_keywords

keywords = summarize_with_keywords(
    texts, min_count=5, max_length=10, beta=0.85, max_iter=10, stopwords=stopwords, verbose=True)
keywords = summarize_with_keywords(texts)  # with default arguments
# Out:
# scan vocabs ...
# num vocabs = 7553
# done = 10

# %%
from wordcloud import WordCloud

# Set your font path
font_path = 'YOUR_FONT_DIR/truetype/nanum/NanumBarunGothic.ttf'

krwordrank_cloud = WordCloud(
    font_path=font_path,
    width=800,
    height=800,
    background_color="white"
)

krwordrank_cloud = krwordrank_cloud.generate_from_frequencies(passwords)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(10, 10))
plt.imshow(krwordrank_cloud, interpolation="bilinear")
plt.show()

# %%
# fig.savefig('./lwordcloud_result.png')
